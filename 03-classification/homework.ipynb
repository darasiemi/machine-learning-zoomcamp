# %% [markdown]
# ### HW3

# %%
import numpy as np
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv
# Out:
# --2025-10-11 13:07:15--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80876 (79K) [text/plain]
# Saving to: ‘course_lead_scoring.csv.2’
#
# course_lead_scoring 100%[===================>]  78.98K  --.-KB/s    in 0.02s
#
# 2025-10-11 13:07:15 (3.83 MB/s) - ‘course_lead_scoring.csv.2’ saved [80876/80876]

# %%
df = pd.read_csv("course_lead_scoring.csv")

# %%
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads         NaN                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3               NaN      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %% [markdown]
# ### Question 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lead_source               1334 non-null   object
#  1   industry                  1328 non-null   object
#  2   number_of_courses_viewed  1462 non-null   int64
#  3   annual_income             1281 non-null   float64
#  4   employment_status         1362 non-null   object
#  5   location                  1399 non-null   object
#  6   interaction_count         1462 non-null   int64
#  7   lead_score                1462 non-null   float64
#  8   converted                 1462 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 102.9+ KB

# %%
categorical = [column for column in df.columns if df[column].dtypes == "object"]
categorical
# Out:
# ['lead_source', 'industry', 'employment_status', 'location']

# %%
numerical = [column for column in df.columns if column not in categorical]

# %%
numerical.remove("converted")

# %%
df[numerical].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number_of_courses_viewed  1462 non-null   int64
#  1   annual_income             1281 non-null   float64
#  2   interaction_count         1462 non-null   int64
#  3   lead_score                1462 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 45.8 KB

# %%
df[categorical].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   lead_source        1334 non-null   object
#  1   industry           1328 non-null   object
#  2   employment_status  1362 non-null   object
#  3   location           1399 non-null   object
# dtypes: object(4)
# memory usage: 45.8+ KB

# %%
df[categorical].isnull().sum()
# Out:
# lead_source          128
# industry             134
# employment_status    100
# location              63
# dtype: int64

# %%
df[categorical] = df[categorical].fillna("NA")

# %%
df[numerical] = df[numerical].fillna(0)

# %%
df.industry.mode()
# Out:
# 0    retail
# Name: industry, dtype: object

# %%
df.industry.value_counts()
# Out:
# industry
# retail           203
# finance          200
# other            198
# healthcare       187
# education        187
# technology       179
# manufacturing    174
# NA               134
# Name: count, dtype: int64

# %% [markdown]
# ### Question 2

# %%
correlation_matrix = {}
for column1 in numerical:
    for column2 in numerical:
        if column1 != column2:
            correlation_matrix[column1 + " and " + column2] = df[column1].corr(df[column2])
correlation_matrix
# Out:
# {'number_of_courses_viewed and annual_income': 0.009770285756444634,
#  'number_of_courses_viewed and interaction_count': -0.023565222882888086,
#  'number_of_courses_viewed and lead_score': -0.00487899835468123,
#  'annual_income and number_of_courses_viewed': 0.009770285756444634,
#  'annual_income and interaction_count': 0.02703647240481435,
#  'annual_income and lead_score': 0.015609546050138897,
#  'interaction_count and number_of_courses_viewed': -0.023565222882888086,
#  'interaction_count and annual_income': 0.02703647240481435,
#  'interaction_count and lead_score': 0.009888182496913115,
#  'lead_score and number_of_courses_viewed': -0.004878998354681231,
#  'lead_score and annual_income': 0.015609546050138897,
#  'lead_score and interaction_count': 0.009888182496913115}

# %%
sorted(correlation_matrix.items(), key=lambda kv: kv[1], reverse = True)
# Out:
# [('annual_income and interaction_count', 0.02703647240481435),
#  ('interaction_count and annual_income', 0.02703647240481435),
#  ('annual_income and lead_score', 0.015609546050138897),
#  ('lead_score and annual_income', 0.015609546050138897),
#  ('interaction_count and lead_score', 0.009888182496913115),
#  ('lead_score and interaction_count', 0.009888182496913115),
#  ('number_of_courses_viewed and annual_income', 0.009770285756444634),
#  ('annual_income and number_of_courses_viewed', 0.009770285756444634),
#  ('number_of_courses_viewed and lead_score', -0.00487899835468123),
#  ('lead_score and number_of_courses_viewed', -0.004878998354681231),
#  ('number_of_courses_viewed and interaction_count', -0.023565222882888086),
#  ('interaction_count and number_of_courses_viewed', -0.023565222882888086)]

# %% [markdown]
# ### Question 3

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
assert len(df_train) + len(df_val) + len(df_test) == df.shape[0]

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.converted.values
y_val = df_val.converted.values
y_test = df_test.converted.values

del df_train['converted']
del df_val['converted']
del df_test['converted']

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_scores = {}

for column in categorical:
    score = mutual_info_score(df_full_train.converted, df_full_train[column])
    mutual_scores[column] = round(score,2)
sorted(mutual_scores.items(), key=lambda kv: kv[1], reverse = True)
# Out:
# [('lead_source', 0.03),
#  ('industry', 0.01),
#  ('employment_status', 0.01),
#  ('location', 0.0)]

# %% [markdown]
# ### Question 4

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
# solver='lbfgs' is the default solver in newer version of sklearn
# for older versions, you need to specify it explicitly
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
y_pred = model.predict_proba(X_val)[:, 1]

# %%
converted = (y_pred >= 0.5)

# %%
(y_val == converted).mean()
# Out:
# 0.6996587030716723

# %%
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = converted.astype(int)
df_pred['actual'] = y_val

# %%
df_pred['correct'] = df_pred.prediction == df_pred.actual

# %%
df_pred.correct.mean()
# Out:
# 0.6996587030716723
